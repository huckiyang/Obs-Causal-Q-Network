# %% [markdown]
# # Training a Resilient Q-Network against Observational Interference, Causal Inference Q-Networks
#
# - Apache 2.0 License: Free Academic and Commericial Use.
#
# - Chao-Han Huck Yang and I-Te Danny Hung et al. 2022 Jan Colab Demo
#
# [Preprint](https://arxiv.org/pdf/2102.09677.pdf) | [Slides](https://docs.google.com/presentation/d/1WOgnMKszZ6eYwxiR0jLZjrj7XbmKpEf9sNrbI8poSMg/edit?usp=sharing) | [Colab Demo](https://colab.research.google.com/drive/1W0muo9IQMsQUIc4nLbB5VOKg7aXuWFR2?usp=sharing) |
# ![PyTorch](https://img.shields.io/badge/PyTorch-%23EE4C2C.svg?style=for-the-badge&logo=PyTorch&logoColor=white)

# %%
! git clone https://github.com/huckiyang/Obs-Causal-Q-Network
# Out:
# Cloning into 'Obs-Causal-Q-Network'...
# remote: Enumerating objects: 461, done.
# remote: Counting objects: 100% (446/446), done.
# remote: Compressing objects: 100% (392/392), done.
# remote: Total 461 (delta 127), reused 323 (delta 46), pack-reused 15
# Receiving objects: 100% (461/461), 47.42 MiB | 5.65 MiB/s, done.
# Resolving deltas: 100% (131/131), done.

# %%
# %cd Obs-Causal-Q-Network 
## running is ok with existing pytorch and gym packages naturally in Colab by Jan 2022
# Out:
# /content/Obs-Causal-Q-Network

# %% [markdown]
# ### Causal Inference Q-Network Architecture
#
# ![ciq_cartpole.png](data:image/png;base64,...)

# %%
! python 0-cartpole-main.py --network 1
# Out:
# observation space: Box(-3.4028234663852886e+38, 3.4028234663852886e+38, (4,), float32)
# action space: Discrete(2)
# Timing Atk Ratio: 10%
# Using CEQNetwork_1. Number of Params: 41872
#  Interference Type: 1  Use baseline:  0 use CGM:  1
# With:  10.42 % timing attack
# Episode 0   Score: 48.00, Average Score: 48.00, Loss: 1.72
# With:  0.0 % timing attack
# Episode 20   Score: 11.00, Average Score: 18.71, Loss: 40.68
# With:  6.0 % timing attack
# Episode 40   Score: 200.00, Average Score: 54.76, Loss: 27.84
# With:  10.5 % timing attack
# Episode 60   Score: 200.00, Average Score: 103.03, Loss: 17.63
# Using CEQNetwork_1. Number of Params: 41872
# ### Evaluation Phase & Report DQNs Test Score : 131.8
# Using CEQNetwork_1. Number of Params: 41872
# ### Evaluation Phase & Report DQNs Test Score : 154.2
# Using CEQNetwork_1. Number of Params: 41872
# ### Evaluation Phase & Report DQNs Test Score : 147.4
# Using CEQNetwork_1. Number of Params: 41872
# ...

# %%
from IPython.display import Image
Image('/content/Obs-Causal-Q-Network/fig_result/reply_0109-2022_Trt0_Atk_wC_1_Net_1_0.1_dqn.png')
